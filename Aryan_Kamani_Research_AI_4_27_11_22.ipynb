# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('CarPrice_Assignment.csv')

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
import seaborn as sns

# %%
df.aspiration.value_counts()
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
df.doornumber.value_counts()
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
df.carbody.value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64

# %%
df.drivewheel.value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
df.enginelocation.value_counts()
# Out:
# front    202
# rear       3
# Name: enginelocation, dtype: int64

# %%
df.fueltype.value_counts()
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64

# %%
df['gas'] = np.where(df['fueltype']=='gas',1,0)
df['diesel'] = np.where(df['fueltype']=='diesel',1,0)
df.drop(columns = ['fueltype'],axis = 1, inplace = True)

# %%
df['aspiaration.std'] = np.where(df['aspiration']=='std',1,0)
df['aspiration.turbo'] = np.where(df['aspiration']=='turbo',1,0)
df.drop(columns = ['aspiration'],axis = 1, inplace = True)

# %%
df['doornumber.four'] = np.where(df['doornumber']=='four',1,0)
df['doornumber.two'] = np.where(df['doornumber']=='two',1,0)
df.drop(columns = ['doornumber'],axis = 1, inplace = True)

# %%
df['enginelocation.front'] = np.where(df['enginelocation']=='four',1,0)
df['enginelocation.rear'] = np.where(df['enginelocation']=='two',1,0)
df.drop(columns = ['enginelocation'],axis = 1, inplace = True)

# %%
df['carbody.sedan'] = np.where(df['carbody']=='sedan',1,0)
df['carbody.hatchback'] = np.where(df['carbody']=='hatchback',1,0)
df['carbody.wagon'] = np.where(df['carbody']=='wagon',1,0)
df['carbody.hardtop'] = np.where(df['carbody']=='hardtop',1,0)
df['carbody.convertible'] = np.where(df['carbody']=='convertible',1,0)
df.drop(columns = ['carbody'],axis = 1, inplace = True)

# %%
df['drivewheel.fwd'] = np.where(df['drivewheel']=='fwd',1,0)
df['drivewheel.rwd'] = np.where(df['drivewheel']=='rwd',1,0)
df['drivewheel.4wd'] = np.where(df['drivewheel']=='4wd',1,0)
df.drop(columns = ['drivewheel'],axis = 1, inplace = True)

# %%
df.drop(columns = ['CarName'],axis = 1, inplace = True)

# %%
df.cylindernumber.value_counts()
# Out:
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: cylindernumber, dtype: int64

# %%
df.enginetype.value_counts()
# Out:
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64

# %%
df.fuelsystem.value_counts()
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuelsystem, dtype: int64

# %%
df['fuelsystem.mpfi'] = np.where(df['fuelsystem']=='mpfi',1,0)
df['fuelsystem.2bbl'] = np.where(df['fuelsystem']=='2bbl',1,0)
df['fuelsystem.idi'] = np.where(df['fuelsystem']=='idi',1,0)
df['fuelsystem.1bbl'] = np.where(df['fuelsystem']=='1bbl',1,0)
df['fuelsystem.spdi'] = np.where(df['fuelsystem']=='spdi',1,0)
df['fuelsystem.4bbl'] = np.where(df['fuelsystem']=='4bbl',1,0)
df['fuelsystem.mfi'] = np.where(df['fuelsystem']=='mfi',1,0)
df['fuelsystem.spfi'] = np.where(df['fuelsystem']=='spfi',1,0)
df.drop(columns = ['fuelsystem'],axis = 1, inplace = True)

# %%
df['enginetype.ohc'] = np.where(df['enginetype']=='ohc',1,0)
df['enginetype.ohcf'] = np.where(df['enginetype']=='ohcf',1,0)
df['enginetype.ohcv'] = np.where(df['enginetype']=='ohcv',1,0)
df['enginetype.dohc'] = np.where(df['enginetype']=='dohc',1,0)
df['enginetype.1'] = np.where(df['enginetype']=='1',1,0)
df['enginetype.rotor'] = np.where(df['enginetype']=='rotor',1,0)
df['enginetype.dohcv'] = np.where(df['enginetype']=='dohcv',1,0)
df.drop(columns = ['enginetype'],axis = 1, inplace = True)

# %%
df['cylindernumber.four'] = np.where(df['cylindernumber']=='four',1,0)
df['cylindernumber.six'] = np.where(df['cylindernumber']=='six',1,0)
df['cylindernumber.five'] = np.where(df['cylindernumber']=='five',1,0)
df['cylindernumber.eight'] = np.where(df['cylindernumber']=='eight',1,0)
df['cylindernumber.two'] = np.where(df['cylindernumber']=='two',1,0)
df['cylindernumber.three'] = np.where(df['cylindernumber']=='three',1,0)
df['cylindernumber.twelve'] = np.where(df['cylindernumber']=='twelve',1,0)
df.drop(columns = ['cylindernumber'],axis = 1, inplace = True)

# %%
df
# Out:
#      car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0         1          3       88.6      168.8      64.1       48.8        2548
# 1         2          3       88.6      168.8      64.1       48.8        2548
# 2         3          1       94.5      171.2      65.5       52.4        2823
# 3         4          2       99.8      176.6      66.2       54.3        2337
# 4         5          2       99.4      176.6      66.4       54.3        2824
# ..      ...        ...        ...        ...       ...        ...         ...
# 200     201         -1      109.1      188.8      68.9       55.5        2952
# 201     202         -1      109.1      188.8      68.8       55.5        3049
# 202     203         -1      109.1      188.8      68.9       55.5        3012
# 203     204         -1      109.1      188.8      68.9       55.5        3217
# 204     205         -1      109.1      188.8      68.9       55.5        3062
#
# ...

# %%
dependent_var = 'price'

# %%
independent_var = df.columns

# %%
independent_var = independent_var.drop(dependent_var)

# %%
independent_var
# Out:
# Index(['car_ID', 'symboling', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'gas', 'diesel', 'aspiaration.std', 'aspiration.turbo',
#        'doornumber.four', 'doornumber.two', 'enginelocation.front',
#        'enginelocation.rear', 'carbody.sedan', 'carbody.hatchback',
#        'carbody.wagon', 'carbody.hardtop', 'carbody.convertible',
#        'drivewheel.fwd', 'drivewheel.rwd', 'drivewheel.4wd', 'fuelsystem.mpfi',
#        'fuelsystem.2bbl', 'fuelsystem.idi', 'fuelsystem.1bbl',
#        'fuelsystem.spdi', 'fuelsystem.4bbl', 'fuelsystem.mfi',
#        'fuelsystem.spfi', 'enginetype.ohc', 'enginetype.ohcf',
#        'enginetype.ohcv', 'enginetype.dohc', 'enginetype.1',
#        'enginetype.rotor', 'enginetype.dohcv', 'cylindernumber.four',
#        'cylindernumber.six', 'cylindernumber.five', 'cylindernumber.eight',
# ...

# %%
X = df[independent_var].values
Y = df[dependent_var].values

# %%
# Converting to a standardised form where all the values lie between 0 and 1
X_std = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))
# Out:
# /var/folders/gc/3sqxc6dd4vx89q51lg2ztcwm0000gn/T/ipykernel_354/2622959724.py:2: RuntimeWarning: invalid value encountered in true_divide
#   X_std = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))

# %%
X_std
# Out:
# array([[0.        , 1.        , 0.05830904, ..., 0.        , 0.        ,
#         0.        ],
#        [0.00490196, 1.        , 0.05830904, ..., 0.        , 0.        ,
#         0.        ],
#        [0.00980392, 0.6       , 0.2303207 , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.99019608, 0.2       , 0.65597668, ..., 0.        , 0.        ,
#         0.        ],
#        [0.99509804, 0.2       , 0.65597668, ..., 0.        , 0.        ,
#         0.        ],
#        [1.        , 0.2       , 0.65597668, ..., 0.        , 0.        ,
#         0.        ]])

# %%
import matplotlib.pyplot as plt

# %%
x1 = df.wheelbase

# %%
x1
# Out:
# 0       88.6
# 1       88.6
# 2       94.5
# 3       99.8
# 4       99.4
#        ...
# 200    109.1
# 201    109.1
# 202    109.1
# 203    109.1
# 204    109.1
# Name: wheelbase, Length: 205, dtype: float64

# %%
plt.scatter(x1,Y)

# %%
x1mean = x1.mean()

# %%
x1mean
# Out:
# 98.75658536585378

# %%
ssxx1 = ((x1mean - x1)**2).sum()

# %%
ssxx1
# Out:
# 7397.4036097560975

# %%
Ymean = Y.mean()

# %%
Ymean
# Out:
# 13276.710570731706

# %%
ssxy = ((Ymean - Y)*(x1mean - x1)).sum()

# %%
ssxy
# Out:
# 5670591.940979512

# %%
m1 = ssxy/ssxx1

# %%
m
# Out:
# 205

# %%
b = Ymean - m*x1mean

# %%
b
# Out:
# -6968.389429268318

# %%
Ypredict = m*x1 + b

# %%
lineStartX = x1.min() 
lineEndX = x1.max()

lineStartY = Ypredict.min() 
lineEndY = Ypredict.max()  

plt.figure()
plt.scatter(x1, Y, color = 'k', alpha=0.5)
plt.plot([lineStartX,lineEndX], [lineStartY, lineEndY], 'k-', color = 'r')
plt.show()
# Out:
# /var/folders/gc/3sqxc6dd4vx89q51lg2ztcwm0000gn/T/ipykernel_354/1616639603.py:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([lineStartX,lineEndX], [lineStartY, lineEndY], 'k-', color = 'r')

# %%
corr = df.corr()

# %%
corr[corr>0.7]
# Out:
#                        car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID                    1.0        NaN        NaN        NaN       NaN
# symboling                 NaN        1.0        NaN        NaN       NaN
# wheelbase                 NaN        NaN   1.000000   0.874587  0.795144
# carlength                 NaN        NaN   0.874587   1.000000  0.841118
# carwidth                  NaN        NaN   0.795144   0.841118  1.000000
# carheight                 NaN        NaN        NaN        NaN       NaN
# curbweight                NaN        NaN   0.776386   0.877728  0.867032
# enginesize                NaN        NaN        NaN        NaN  0.735433
# boreratio                 NaN        NaN        NaN        NaN       NaN
# stroke                    NaN        NaN        NaN        NaN       NaN
# compressionratio          NaN        NaN        NaN        NaN       NaN
# horsepower                NaN        NaN        NaN        NaN       NaN
# ...

# %%
df.drop(columns= ['wheelbase','carlength','carwidth','curbweight','enginesize','horsepower','cylindernumber.two'],axis = 1,inplace = True)

# %%
corr = df.corr()

# %%
corr[corr>0.7]
# Out:
#                        car_ID  symboling  carheight  boreratio  stroke  \
# car_ID                    1.0        NaN        NaN        NaN     NaN
# symboling                 NaN        1.0        NaN        NaN     NaN
# carheight                 NaN        NaN        1.0        NaN     NaN
# boreratio                 NaN        NaN        NaN        1.0     NaN
# stroke                    NaN        NaN        NaN        NaN     1.0
# compressionratio          NaN        NaN        NaN        NaN     NaN
# peakrpm                   NaN        NaN        NaN        NaN     NaN
# citympg                   NaN        NaN        NaN        NaN     NaN
# highwaympg                NaN        NaN        NaN        NaN     NaN
# price                     NaN        NaN        NaN        NaN     NaN
# gas                       NaN        NaN        NaN        NaN     NaN
# diesel                    NaN        NaN        NaN        NaN     NaN
# ...

# %%
df.drop(columns = ['fuelsystem.idi','compressionratio','citympg','highwaympg','diesel','enginetype.rotor'],axis = 1, inplace = True)

# %%
corr = df.corr()

# %%
corr[corr>0.7]
# Out:
#                        car_ID  symboling  carheight  boreratio  stroke  \
# car_ID                    1.0        NaN        NaN        NaN     NaN
# symboling                 NaN        1.0        NaN        NaN     NaN
# carheight                 NaN        NaN        1.0        NaN     NaN
# boreratio                 NaN        NaN        NaN        1.0     NaN
# stroke                    NaN        NaN        NaN        NaN     1.0
# peakrpm                   NaN        NaN        NaN        NaN     NaN
# price                     NaN        NaN        NaN        NaN     NaN
# gas                       NaN        NaN        NaN        NaN     NaN
# aspiaration.std           NaN        NaN        NaN        NaN     NaN
# aspiration.turbo          NaN        NaN        NaN        NaN     NaN
# doornumber.four           NaN        NaN        NaN        NaN     NaN
# doornumber.two            NaN        NaN        NaN        NaN     NaN
# ...

# %%
df.shape
# Out:
# (205, 41)

# %%
df
# Out:
#      car_ID  symboling  carheight  boreratio  stroke  peakrpm    price  gas  \
# 0         1          3       48.8       3.47    2.68     5000  13495.0    1
# 1         2          3       48.8       3.47    2.68     5000  16500.0    1
# 2         3          1       52.4       2.68    3.47     5000  16500.0    1
# 3         4          2       54.3       3.19    3.40     5500  13950.0    1
# 4         5          2       54.3       3.19    3.40     5500  17450.0    1
# ..      ...        ...        ...        ...     ...      ...      ...  ...
# 200     201         -1       55.5       3.78    3.15     5400  16845.0    1
# 201     202         -1       55.5       3.78    3.15     5300  19045.0    1
# 202     203         -1       55.5       3.58    2.87     5500  21485.0    1
# 203     204         -1       55.5       3.01    3.40     4800  22470.0    0
# 204     205         -1       55.5       3.78    3.15     5400  22625.0    1
#
# ...

# %%
x1 = df.carheight
x2 = df.boreratio
Y = df.price

# %%
# Ypredict = x1*b1 + x2*b2 + a
def Ypredict(x1,x2,a,b1,b2):
    return x1*b1 + x2*b2 + a

# %%
m = 205

# %%
def J(b1,b2):
    return (1/(2*m))*(((Ypredict(x1,x2,a,b,b1)-Y)**2).sum())

# %%
from sympy import symbols, diff

# %%
x1, x2, Y , b1 ,b2 , a = symbols('x1 x2 Y b1 b2 a', real=True)

# %%
alpha = 0.3

# %%
th1 = np.zeros((205,1))
th2 = np.zeros((205,1))
th0 = np.zeros((205,1))

# %%
x1 = x1.to_numpy()
x2 = x2.to_numpy()
Y = Y.to_numpy()

# %%
x1.shape
# Out:
# (205,)

# %%
iteration = 205

# %%
cost_history = np.zeros(iteration)
theta_history = np.zeros((iteration,2))
for i in range(iteration):
    prediction = np.sum(np.dot(x1,th1),np.dot(x2,th2),th0)
    th1 = th1 - (1/m)*learning_rate*(x1.T.dot((np.subtract(prediction,y)))
    th2 = th2 - (1/m)*learning_rate*(x2.T.dot((np.subtract(prediction,y)))
    th0 = th0 - (1/m)*learning_rate*(np.dot((np.subtract(prediction,y)))
    
    net = 1/(2*m)*np.sum(np.power(np.subtract(np.add(np.dot(x1,th1),np.dot(x2,th2),th0),Y),2))
    cost_history[i,:] = net
# Out:
#   File "/var/folders/gc/3sqxc6dd4vx89q51lg2ztcwm0000gn/T/ipykernel_354/2407884452.py", line 6
#     th2 = th2 - (1/m)*learning_rate*(x2.T.dot((np.subtract(prediction,y)))
#     ^
# SyntaxError: invalid syntax
